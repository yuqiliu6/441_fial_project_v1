# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
import shutil
navoneel_brain_mri_images_for_brain_tumor_detection_path = kagglehub.dataset_download('navoneel/brain-mri-images-for-brain-tumor-detection')
save_path = "/content/drive/My Drive/CS441/MRI"
shutil.move(navoneel_brain_mri_images_for_brain_tumor_detection_path, save_path)
# Out:
# '/content/drive/My Drive/CS441/MRI/1'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import cv2
import os
import matplotlib.pyplot as plt

# %%
def load_images(image_folder, target_size):
    images = []
    labels = []
    folder0 = image_folder + "/no"
    folder1 = image_folder + "/yes"
    for _, _, filenames in os.walk(folder0):
        for filename in filenames:
            path = folder0 + '/' + filename
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, target_size)
            images.append(img.flatten())
            labels.append(0)
    for _, _, filenames in os.walk(folder1):
        for filename in filenames:
            path = folder1 + '/' + filename
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, target_size)
            images.append(img.flatten())
            labels.append(1)
    return np.array(images), np.array(labels)

# %%
image_folder = "/content/drive/My Drive/CS441/MRI/brain_tumor_dataset"
size = (224,224)
images, labels = load_images(image_folder, size)

# %%
indices = np.arange(len(images))
np.random.shuffle(indices)
images = images[indices]
labels = labels[indices]

# %%
# KNN
train_X = images[:177]
train_y = labels[:177]
val_X = images[177:215]
val_y = labels[177:215]
test_X = images[215:]
test_y = labels[215:]

# %%
def KNN_predict(X, y, X_query, k, weighted):
    neighbor_dist = np.sqrt(np.sum((X_query - X)**2, axis=1))
    indices = np.argsort(neighbor_dist)[:k]
    neighbor_y = y[indices]

    if weighted:
        dist = neighbor_dist[indices]
        weights = 1 / (dist + 1e-10)
        pred = np.sum(neighbor_y * weights) / np.sum(weights)
    else:
        pred = np.mean(neighbor_y)

    label = 1 if pred > 0.5 else 0
    return label

# %%
def evaluate(train_X, test_X, train_y, test_y, k, weighted):
    correct = 0
    for i in range(len(test_X)):
        if KNN_predict(train_X,train_y,test_X[i], k, weighted) == test_y[i]:
            correct += 1
    return correct/len(test_y)

# %%
k_val = [1,3,5,7,9]
accuracy_uw = []
accuracy_w = []
for k in k_val:
    accuracy_uw.append(evaluate(train_X, val_X, train_y, val_y, k, 0))
    accuracy_w.append(evaluate(train_X, val_X, train_y, val_y, k, 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_val, accuracy_uw, label = "unweighted", marker='o')
plt.plot(k_val, accuracy_w, label = "weighted", marker='o')
plt.title('Accuracy vs K')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(evaluate(train_X, test_X, train_y, test_y, 7, 1))
# Out:
# 0.7631578947368421

# %%
# PCA + random forest
scaler = StandardScaler()
images = scaler.fit_transform(images)
pca = PCA(n_components=25)
images_pca = pca.fit_transform(images)
train_X = images_pca[:177]
train_y = labels[:177]
val_X = images_pca[177:215]
val_y = labels[177:215]
test_X = images_pca[215:]
test_y = labels[215:]

feature_num = [2, 5, 10, 18, 25]
tree_num = [100,300,500]
accuracy_array = np.zeros((3,5))
for i in range(len(tree_num)):
    for j in range(len(feature_num)):
        rf_model = RandomForestClassifier(n_estimators=tree_num[i], random_state=42, max_features=feature_num[j])
        rf_model.fit(train_X, train_y)
        pred = rf_model.predict(val_X)
        accuracy = accuracy_score(val_y, pred)
        accuracy_array[i][j] = accuracy

# %%
# Plotting
plt.figure(figsize=(10, 6))
for i, tree in enumerate(tree_num):
    plt.plot(feature_num, accuracy_array[i], label=f'{tree} Trees', marker='o')

plt.title('Accuracy vs Feature Number for Different Tree Counts')
plt.xlabel('Number of Features')
plt.ylabel('Accuracy')
plt.legend(title='Number of Trees')
plt.grid(True)
plt.show()

# %%
rf_model = RandomForestClassifier(n_estimators=500, random_state=42, max_features=5)
rf_model.fit(train_X, train_y)
pred = rf_model.predict(test_X)
accuracy = accuracy_score(test_y, pred)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 92.11%

# %%
# Deep Learing (CNN)
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
from torch.utils.data import random_split
from sklearn.metrics import accuracy_score
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
save_dir = "/content/drive/My Drive/CS441/MRI"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
path = "/content/drive/My Drive/CS441/MRI/brain_tumor_dataset"

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(path, transform=train_transform)
test_dataset = datasets.ImageFolder(path, transform=test_transform)

dataset_size = len(train_dataset)
train_end = int(0.7 * dataset_size)
val_end = int(0.85 * dataset_size)
test_end = dataset_size

train_indices = list(range(0, train_end))
val_indices = list(range(train_end, val_end))
test_indices = list(range(val_end, test_end))

train_dataset = Subset(train_dataset, train_indices)
val_dataset = Subset(test_dataset, val_indices)
test_dataset = Subset(test_dataset, test_indices)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

# %%
def initializeModel(num_target_classes = 2):
  # loads a pre-trained ResNet-34 model
  model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet34', pretrained=True)

  in_features = model.fc.in_features
  model.fc = nn.Linear(in_features, num_target_classes)

  for name, param in model.named_parameters():
    param.requires_grad = True
  # for name, param in model.named_parameters():
  #   if "layer4" in name or "fc" in name:
  #       param.requires_grad = True
  #   else:
  #       param.requires_grad = False
  model = model.to(device)

  return model

# %%
def train(train_loader, model, criterion, optimizer):
    model.train()
    loss_ = 0.0
    losses = []

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        pred = model(images)
        loss = criterion(pred, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

def test(test_loader, model, criterion):
    model.eval()
    losses = []
    correct = 0
    total = 0
    for images, labels in test_loader:
      images, labels = images.to(device), labels.to(device)
      with torch.no_grad():
       output = model(images)
      preds = torch.argmax(output, dim=-1)
      loss = criterion(output, labels)
      losses.append(loss.item())
      correct += (preds == labels).sum().item()
      total += len(labels)

    mean_accuracy = correct / total
    test_loss = np.mean(losses)
    print('Mean Accuracy: {0:.4f}'.format(mean_accuracy))
    print('Avg loss: {}'.format(test_loss))

    return mean_accuracy, test_loss

# %%
# Plot loss or accuracy
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0 or i == 1)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

def plot_accuracy(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0 or i == 1)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("Accuracy Plot")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

def save_checkpoint(save_dir, model, save_name):
    save_path = os.path.join(save_dir, save_name)
    torch.save(model.state_dict(), save_path)

def load_model(model, save_dir, save_name):
    save_path = os.path.join(save_dir, save_name)
    model.load_state_dict(torch.load(save_path))
    return model

# %%
epochs = 20
def train_epoch(train_loader, learn_rate, max_accuracy):
  model = initializeModel()
  model = model.to(device)
  optimizer = torch.optim.SGD(model.parameters(), lr=learn_rate, weight_decay = 0.005, momentum = 0.9)
  lr_scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: min(1, epoch / 5))
  criterion = torch.nn.CrossEntropyLoss()
  train_losses = []
  train_accuracy_list = []
  test_losses = []
  test_accuracy_list = []
  for epoch in range(epochs):
      # Train the network for one epoch
      train_loss = train(train_loader, model, criterion, optimizer)

      # TO DO: uncomment the line below. It should be called each epoch to apply the lr_scheduler
      lr_scheduler.step()

      train_losses.append(train_loss)
      print(f'Loss for Training on epoch {str(epoch)} is {str(train_loss)} \n')

      # Get the train accuracy and test loss/accuracy
      print('Evaluating Network')

      train_accuracy, _ = test(train_loader, model, criterion) # Get training accuracy
      train_accuracy_list.append(train_accuracy)

      print(f'Training accuracy on epoch {str(epoch)} is {str(train_accuracy)} \n')

      test_accuracy, test_loss = test(test_loader, model, criterion) # Get testing accuracy and error
      test_losses.append(test_loss)
      test_accuracy_list.append(test_accuracy)
      print(f'Test (val) accuracy on epoch {str(epoch)} is {str(test_accuracy)} \n')

      # Checkpoints are used to save the model with best validation accuracy
      if test_accuracy >= max(test_accuracy_list):
        print("Saving Model")
        name = 'best_model' + str(learn_rate)+ '.pth'
        save_checkpoint(save_dir, model, save_name = name) # Save model with best performance
  plot_losses(train_losses, test_losses, 1, epochs)
  plot_accuracy(train_accuracy_list, test_accuracy_list, 1, epochs)
  return max(test_accuracy_list)

# %%
learning_rate = [0.01, 0.005, 0.001]
max_accuracy = 0
for lr in learning_rate:
  new_max = train_epoch(train_loader, lr, max_accuracy)

  print("---------------------------------------")
  print(max_accuracy)
  print("---------------------------------------")
  if new_max > max_accuracy:
    max_accuracy = new_max
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Loss for Training on epoch 0 is 0.7901452779769897
#
# Evaluating Network
# Mean Accuracy: 0.5198
# Avg loss: 0.7514812548955282
# Training accuracy on epoch 0 is 0.519774011299435
#
# Mean Accuracy: 0.0263
# Avg loss: 1.113172471523285
# Test (val) accuracy on epoch 0 is 0.02631578947368421
#
# Saving Model
# Loss for Training on epoch 1 is 0.5916913747787476
#
# Evaluating Network
# Mean Accuracy: 0.7740
# Avg loss: 0.4538894643386205
# Training accuracy on epoch 1 is 0.7740112994350282
#
# Mean Accuracy: 0.1842
# Avg loss: 1.3700039982795715
# Test (val) accuracy on epoch 1 is 0.18421052631578946
#
# Saving Model
# Loss for Training on epoch 2 is 0.3469502925872803
#
# Evaluating Network
# Mean Accuracy: 0.8588
# Avg loss: 0.31740717093149823
# Training accuracy on epoch 2 is 0.8587570621468926
#
# Mean Accuracy: 0.3421
# Avg loss: 1.2298727631568909
# Test (val) accuracy on epoch 2 is 0.34210526315789475
#
# Saving Model
# Loss for Training on epoch 3 is 0.11749690771102905
#
# Evaluating Network
# Mean Accuracy: 0.8870
# Avg loss: 0.3048405374089877
# Training accuracy on epoch 3 is 0.8870056497175142
#
# Mean Accuracy: 0.9474
# Avg loss: 0.10910533554852009
# Test (val) accuracy on epoch 3 is 0.9473684210526315
#
# Saving Model
# Loss for Training on epoch 4 is 0.19838248193264008
#
# Evaluating Network
# Mean Accuracy: 0.9322
# Avg loss: 0.18794007413089275
# Training accuracy on epoch 4 is 0.9322033898305084
#
# Mean Accuracy: 0.9474
# Avg loss: 0.14612634479999542
# Test (val) accuracy on epoch 4 is 0.9473684210526315
#
# Saving Model
# Loss for Training on epoch 5 is 0.16799992322921753
#
# Evaluating Network
# Mean Accuracy: 0.8757
# Avg loss: 0.38683729122082394
# Training accuracy on epoch 5 is 0.8757062146892656
#
# Mean Accuracy: 1.0000
# Avg loss: 0.0067678582163352985
# Test (val) accuracy on epoch 5 is 1.0
#
# Saving Model
# Loss for Training on epoch 6 is 0.14860208332538605
#
# Evaluating Network
# Mean Accuracy: 0.9209
# Avg loss: 0.18779044598340988
# Training accuracy on epoch 6 is 0.9209039548022598
#
# Mean Accuracy: 0.5526
# Avg loss: 0.8765976130962372
# Test (val) accuracy on epoch 6 is 0.5526315789473685
#
# Loss for Training on epoch 7 is 0.16785238683223724
#
# Evaluating Network
# Mean Accuracy: 0.9605
# Avg loss: 0.13845318974927068
# Training accuracy on epoch 7 is 0.96045197740113
#
# Mean Accuracy: 0.8947
# Avg loss: 0.20530430134385824
# Test (val) accuracy on epoch 7 is 0.8947368421052632
#
# Loss for Training on epoch 8 is 0.0714578852057457
#
# Evaluating Network
# Mean Accuracy: 0.9718
# Avg loss: 0.08445709571242332
# Training accuracy on epoch 8 is 0.9717514124293786
#
# Mean Accuracy: 0.7632
# Avg loss: 0.5807812213897705
# Test (val) accuracy on epoch 8 is 0.7631578947368421
#
# Loss for Training on epoch 9 is 0.20212900638580322
#
# Evaluating Network
# Mean Accuracy: 0.9153
# Avg loss: 0.24874587481220564
# Training accuracy on epoch 9 is 0.9152542372881356
#
# Mean Accuracy: 0.6579
# Avg loss: 1.3214099705219269
# Test (val) accuracy on epoch 9 is 0.6578947368421053
#
# Loss for Training on epoch 10 is 0.2715948820114136
#
# Evaluating Network
# Mean Accuracy: 0.9831
# Avg loss: 0.05350464987956608
# Training accuracy on epoch 10 is 0.9830508474576272
#
# Mean Accuracy: 0.9474
# Avg loss: 0.09436281584203243
# Test (val) accuracy on epoch 10 is 0.9473684210526315
#
# Loss for Training on epoch 11 is 0.22440874576568604
#
# Evaluating Network
# Mean Accuracy: 0.9435
# Avg loss: 0.11300609881679217
# Training accuracy on epoch 11 is 0.943502824858757
#
# Mean Accuracy: 0.6579
# Avg loss: 0.5522071793675423
# Test (val) accuracy on epoch 11 is 0.6578947368421053
#
# Loss for Training on epoch 12 is 0.2457607388496399
#
# Evaluating Network
# Mean Accuracy: 0.9153
# Avg loss: 0.2666181077559789
# Training accuracy on epoch 12 is 0.9152542372881356
#
# Mean Accuracy: 0.6579
# Avg loss: 1.44620019197464
# Test (val) accuracy on epoch 12 is 0.6578947368421053
#
# Loss for Training on epoch 13 is 0.19315163791179657
#
# Evaluating Network
# Mean Accuracy: 0.9379
# Avg loss: 0.19735530007164925
# Training accuracy on epoch 13 is 0.9378531073446328
#
# Mean Accuracy: 0.9737
# Avg loss: 0.028583917883224785
# Test (val) accuracy on epoch 13 is 0.9736842105263158
#
# Loss for Training on epoch 14 is 0.06670084595680237
#
# Evaluating Network
# Mean Accuracy: 0.9322
# Avg loss: 0.22932909429073334
# Training accuracy on epoch 14 is 0.9322033898305084
#
# Mean Accuracy: 0.8158
# Avg loss: 0.26729394495487213
# Test (val) accuracy on epoch 14 is 0.8157894736842105
#
# Loss for Training on epoch 15 is 0.08004122972488403
#
# Evaluating Network
# Mean Accuracy: 0.9774
# Avg loss: 0.05383049696683884
# Training accuracy on epoch 15 is 0.9774011299435028
#
# Mean Accuracy: 0.9474
# Avg loss: 0.11271851044148207
# Test (val) accuracy on epoch 15 is 0.9473684210526315
#
# Loss for Training on epoch 16 is 0.048065271228551865
#
# Evaluating Network
# Mean Accuracy: 0.9661
# Avg loss: 0.08990281804775198
# Training accuracy on epoch 16 is 0.9661016949152542
#
# Mean Accuracy: 0.6842
# Avg loss: 2.0526488423347473
# Test (val) accuracy on epoch 16 is 0.6842105263157895
#
# Loss for Training on epoch 17 is 0.09534289687871933
#
# Evaluating Network
# Mean Accuracy: 0.9718
# Avg loss: 0.06583157973363996
# Training accuracy on epoch 17 is 0.9717514124293786
#
# Mean Accuracy: 0.6842
# Avg loss: 1.0067269802093506
# Test (val) accuracy on epoch 17 is 0.6842105263157895
#
# Loss for Training on epoch 18 is 0.21591982245445251
#
# Evaluating Network
# Mean Accuracy: 0.6045
# Avg loss: 1.616109589735667
# Training accuracy on epoch 18 is 0.6045197740112994
#
# Mean Accuracy: 1.0000
# Avg loss: 0.0011317228036205051
# Test (val) accuracy on epoch 18 is 1.0
#
# Saving Model
# Loss for Training on epoch 19 is 0.11773797124624252
#
# Evaluating Network
# Mean Accuracy: 0.9040
# Avg loss: 0.2576323213676612
# Training accuracy on epoch 19 is 0.903954802259887
#
# Mean Accuracy: 0.8158
# Avg loss: 0.30453365575522184
# Test (val) accuracy on epoch 19 is 0.8157894736842105
# ---------------------------------------
# 0
# ---------------------------------------
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Loss for Training on epoch 0 is 0.775993287563324
#
# Evaluating Network
# Mean Accuracy: 0.3616
# Avg loss: 0.8636252582073212
# Training accuracy on epoch 0 is 0.3615819209039548
#
# Mean Accuracy: 0.3684
# Avg loss: 0.7639484405517578
# Test (val) accuracy on epoch 0 is 0.3684210526315789
#
# Saving Model
# Loss for Training on epoch 1 is 0.6447864770889282
#
# Evaluating Network
# Mean Accuracy: 0.5876
# Avg loss: 0.6363847553730011
# Training accuracy on epoch 1 is 0.5875706214689266
#
# Mean Accuracy: 0.0263
# Avg loss: 1.2890053987503052
# Test (val) accuracy on epoch 1 is 0.02631578947368421
#
# Loss for Training on epoch 2 is 0.3642730414867401
#
# Evaluating Network
# Mean Accuracy: 0.8757
# Avg loss: 0.34865378091732663
# Training accuracy on epoch 2 is 0.8757062146892656
#
# Mean Accuracy: 0.8421
# Avg loss: 0.4590041786432266
# Test (val) accuracy on epoch 2 is 0.8421052631578947
#
# Saving Model
# Loss for Training on epoch 3 is 0.33801302313804626
#
# Evaluating Network
# Mean Accuracy: 0.9661
# Avg loss: 0.12366403639316559
# Training accuracy on epoch 3 is 0.9661016949152542
#
# Mean Accuracy: 0.7105
# Avg loss: 0.5619890987873077
# Test (val) accuracy on epoch 3 is 0.7105263157894737
#
# Loss for Training on epoch 4 is 0.26000845432281494
#
# Evaluating Network
# Mean Accuracy: 0.9492
# Avg loss: 0.13832866152127585
# Training accuracy on epoch 4 is 0.9491525423728814
#
# Mean Accuracy: 0.9737
# Avg loss: 0.11434925720095634
# Test (val) accuracy on epoch 4 is 0.9736842105263158
#
# Saving Model
# Loss for Training on epoch 5 is 0.10484832525253296
#
# Evaluating Network
# Mean Accuracy: 0.9322
# Avg loss: 0.1302134239425262
# Training accuracy on epoch 5 is 0.9322033898305084
#
# Mean Accuracy: 1.0000
# Avg loss: 0.06483331695199013
# Test (val) accuracy on epoch 5 is 1.0
#
# Saving Model
# Loss for Training on epoch 6 is 0.03793950378894806
#
# Evaluating Network
# Mean Accuracy: 0.9887
# Avg loss: 0.03028039645869285
# Training accuracy on epoch 6 is 0.9887005649717514
#
# Mean Accuracy: 0.9474
# Avg loss: 0.13202626910060644
# Test (val) accuracy on epoch 6 is 0.9473684210526315
#
# Loss for Training on epoch 7 is 0.032388824969530106
#
# Evaluating Network
# Mean Accuracy: 0.9096
# Avg loss: 0.2786276936531067
# Training accuracy on epoch 7 is 0.9096045197740112
#
# Mean Accuracy: 1.0000
# Avg loss: 0.001613501470274059
# Test (val) accuracy on epoch 7 is 1.0
#
# Saving Model
# Loss for Training on epoch 8 is 0.010040421038866043
#
# Evaluating Network
# Mean Accuracy: 0.9661
# Avg loss: 0.11142050399212167
# Training accuracy on epoch 8 is 0.9661016949152542
#
# Mean Accuracy: 1.0000
# Avg loss: 0.011479995911940932
# Test (val) accuracy on epoch 8 is 1.0
#
# Saving Model
# Loss for Training on epoch 9 is 0.11978629231452942
#
# Evaluating Network
# Mean Accuracy: 0.9774
# Avg loss: 0.05470172410908466
# Training accuracy on epoch 9 is 0.9774011299435028
#
# Mean Accuracy: 0.9211
# Avg loss: 0.17285126820206642
# Test (val) accuracy on epoch 9 is 0.9210526315789473
#
# Loss for Training on epoch 10 is 0.30063116550445557
#
# Evaluating Network
# Mean Accuracy: 0.9492
# Avg loss: 0.13389146824677786
# Training accuracy on epoch 10 is 0.9491525423728814
#
# Mean Accuracy: 0.7895
# Avg loss: 0.9655530452728271
# Test (val) accuracy on epoch 10 is 0.7894736842105263
#
# Loss for Training on epoch 11 is 0.15774133801460266
#
# Evaluating Network
# Mean Accuracy: 0.9944
# Avg loss: 0.054644390009343624
# Training accuracy on epoch 11 is 0.9943502824858758
#
# Mean Accuracy: 0.9474
# Avg loss: 0.1132277362048626
# Test (val) accuracy on epoch 11 is 0.9473684210526315
#
# Loss for Training on epoch 12 is 0.09290166199207306
#
# Evaluating Network
# Mean Accuracy: 0.9831
# Avg loss: 0.06025533005595207
# Training accuracy on epoch 12 is 0.9830508474576272
#
# Mean Accuracy: 0.9737
# Avg loss: 0.05163343995809555
# Test (val) accuracy on epoch 12 is 0.9736842105263158
#
# Loss for Training on epoch 13 is 0.07137060165405273
#
# Evaluating Network
# Mean Accuracy: 0.9605
# Avg loss: 0.07533879671245813
# Training accuracy on epoch 13 is 0.96045197740113
#
# Mean Accuracy: 0.9737
# Avg loss: 0.13376248255372047
# Test (val) accuracy on epoch 13 is 0.9736842105263158
#
# Loss for Training on epoch 14 is 0.06721034646034241
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.006415725646850963
# Training accuracy on epoch 14 is 1.0
#
# Mean Accuracy: 0.8947
# Avg loss: 0.3181217759847641
# Test (val) accuracy on epoch 14 is 0.8947368421052632
#
# Loss for Training on epoch 15 is 0.03251449391245842
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.010980921719844142
# Training accuracy on epoch 15 is 1.0
#
# Mean Accuracy: 0.9737
# Avg loss: 0.08383013680577278
# Test (val) accuracy on epoch 15 is 0.9736842105263158
#
# Loss for Training on epoch 16 is 0.028420306742191315
#
# Evaluating Network
# Mean Accuracy: 0.9887
# Avg loss: 0.03864776149081687
# Training accuracy on epoch 16 is 0.9887005649717514
#
# Mean Accuracy: 0.9474
# Avg loss: 0.1796683743596077
# Test (val) accuracy on epoch 16 is 0.9473684210526315
#
# Loss for Training on epoch 17 is 0.03708251565694809
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.005510271798508863
# Training accuracy on epoch 17 is 1.0
#
# Mean Accuracy: 0.9211
# Avg loss: 0.3330909311771393
# Test (val) accuracy on epoch 17 is 0.9210526315789473
#
# Loss for Training on epoch 18 is 0.024325832724571228
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.009320505564877143
# Training accuracy on epoch 18 is 1.0
#
# Mean Accuracy: 0.8158
# Avg loss: 0.5814120471477509
# Test (val) accuracy on epoch 18 is 0.8157894736842105
#
# Loss for Training on epoch 19 is 0.013681734912097454
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.004501509596593678
# Training accuracy on epoch 19 is 1.0
#
# Mean Accuracy: 0.8684
# Avg loss: 0.6809288561344147
# Test (val) accuracy on epoch 19 is 0.868421052631579
# ---------------------------------------
# 1.0
# ---------------------------------------
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Loss for Training on epoch 0 is 0.7291735410690308
#
# Evaluating Network
# Mean Accuracy: 0.5706
# Avg loss: 0.6755001743634542
# Training accuracy on epoch 0 is 0.5706214689265536
#
# Mean Accuracy: 0.0789
# Avg loss: 1.1400740146636963
# Test (val) accuracy on epoch 0 is 0.07894736842105263
#
# Saving Model
# Loss for Training on epoch 1 is 0.6967819929122925
#
# Evaluating Network
# Mean Accuracy: 0.6328
# Avg loss: 0.6562768220901489
# Training accuracy on epoch 1 is 0.632768361581921
#
# Mean Accuracy: 0.4737
# Avg loss: 0.719279557466507
# Test (val) accuracy on epoch 1 is 0.47368421052631576
#
# Saving Model
# Loss for Training on epoch 2 is 0.5839928388595581
#
# Evaluating Network
# Mean Accuracy: 0.6723
# Avg loss: 0.5890142718950907
# Training accuracy on epoch 2 is 0.672316384180791
#
# Mean Accuracy: 0.6842
# Avg loss: 0.5886653959751129
# Test (val) accuracy on epoch 2 is 0.6842105263157895
#
# Saving Model
# Loss for Training on epoch 3 is 0.47521013021469116
#
# Evaluating Network
# Mean Accuracy: 0.8305
# Avg loss: 0.4271399825811386
# Training accuracy on epoch 3 is 0.8305084745762712
#
# Mean Accuracy: 0.5000
# Avg loss: 0.7579445242881775
# Test (val) accuracy on epoch 3 is 0.5
#
# Loss for Training on epoch 4 is 0.3432919383049011
#
# Evaluating Network
# Mean Accuracy: 0.8475
# Avg loss: 0.33466281990210217
# Training accuracy on epoch 4 is 0.847457627118644
#
# Mean Accuracy: 0.6053
# Avg loss: 0.6195280402898788
# Test (val) accuracy on epoch 4 is 0.6052631578947368
#
# Loss for Training on epoch 5 is 0.296450674533844
#
# Evaluating Network
# Mean Accuracy: 0.9209
# Avg loss: 0.23481728633244833
# Training accuracy on epoch 5 is 0.9209039548022598
#
# Mean Accuracy: 0.7895
# Avg loss: 0.42207519710063934
# Test (val) accuracy on epoch 5 is 0.7894736842105263
#
# Saving Model
# Loss for Training on epoch 6 is 0.2101854532957077
#
# Evaluating Network
# Mean Accuracy: 0.9548
# Avg loss: 0.16907833019892374
# Training accuracy on epoch 6 is 0.9548022598870056
#
# Mean Accuracy: 0.7105
# Avg loss: 0.49066732823848724
# Test (val) accuracy on epoch 6 is 0.7105263157894737
#
# Loss for Training on epoch 7 is 0.1689404845237732
#
# Evaluating Network
# Mean Accuracy: 0.9661
# Avg loss: 0.12568330764770508
# Training accuracy on epoch 7 is 0.9661016949152542
#
# Mean Accuracy: 0.7105
# Avg loss: 0.4698680490255356
# Test (val) accuracy on epoch 7 is 0.7105263157894737
#
# Loss for Training on epoch 8 is 0.14662393927574158
#
# Evaluating Network
# Mean Accuracy: 0.9944
# Avg loss: 0.08438228070735931
# Training accuracy on epoch 8 is 0.9943502824858758
#
# Mean Accuracy: 0.7895
# Avg loss: 0.32571272552013397
# Test (val) accuracy on epoch 8 is 0.7894736842105263
#
# Saving Model
# Loss for Training on epoch 9 is 0.09974833577871323
#
# Evaluating Network
# Mean Accuracy: 0.9944
# Avg loss: 0.05845900314549605
# Training accuracy on epoch 9 is 0.9943502824858758
#
# Mean Accuracy: 0.7632
# Avg loss: 0.29945918917655945
# Test (val) accuracy on epoch 9 is 0.7631578947368421
#
# Loss for Training on epoch 10 is 0.06932036578655243
#
# Evaluating Network
# Mean Accuracy: 0.9944
# Avg loss: 0.054259562554458775
# Training accuracy on epoch 10 is 0.9943502824858758
#
# Mean Accuracy: 0.7895
# Avg loss: 0.28461360931396484
# Test (val) accuracy on epoch 10 is 0.7894736842105263
#
# Saving Model
# Loss for Training on epoch 11 is 0.06757444143295288
#
# Evaluating Network
# Mean Accuracy: 0.9887
# Avg loss: 0.04786698830624422
# Training accuracy on epoch 11 is 0.9887005649717514
#
# Mean Accuracy: 0.7632
# Avg loss: 0.28795094788074493
# Test (val) accuracy on epoch 11 is 0.7631578947368421
#
# Loss for Training on epoch 12 is 0.07282549142837524
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.03355931397527456
# Training accuracy on epoch 12 is 1.0
#
# Mean Accuracy: 0.8684
# Avg loss: 0.1874641440808773
# Test (val) accuracy on epoch 12 is 0.868421052631579
#
# Saving Model
# Loss for Training on epoch 13 is 0.05849399417638779
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.030664979790647823
# Training accuracy on epoch 13 is 1.0
#
# Mean Accuracy: 0.8684
# Avg loss: 0.1791575290262699
# Test (val) accuracy on epoch 13 is 0.868421052631579
#
# Saving Model
# Loss for Training on epoch 14 is 0.05550163984298706
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.020572014929105837
# Training accuracy on epoch 14 is 1.0
#
# Mean Accuracy: 0.8421
# Avg loss: 0.1986643671989441
# Test (val) accuracy on epoch 14 is 0.8421052631578947
#
# Loss for Training on epoch 15 is 0.026567712426185608
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.01706922457863887
# Training accuracy on epoch 15 is 1.0
#
# Mean Accuracy: 0.8421
# Avg loss: 0.22366706654429436
# Test (val) accuracy on epoch 15 is 0.8421052631578947
#
# Loss for Training on epoch 16 is 0.01487018819898367
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.013453702287127575
# Training accuracy on epoch 16 is 1.0
#
# Mean Accuracy: 0.8421
# Avg loss: 0.2646106854081154
# Test (val) accuracy on epoch 16 is 0.8421052631578947
#
# Loss for Training on epoch 17 is 0.015730172395706177
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.012185123283416033
# Training accuracy on epoch 17 is 1.0
#
# Mean Accuracy: 0.7895
# Avg loss: 0.3084012642502785
# Test (val) accuracy on epoch 17 is 0.7894736842105263
#
# Loss for Training on epoch 18 is 0.020002877339720726
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.010925513071318468
# Training accuracy on epoch 18 is 1.0
#
# Mean Accuracy: 0.7632
# Avg loss: 0.3506321907043457
# Test (val) accuracy on epoch 18 is 0.7631578947368421
#
# Loss for Training on epoch 19 is 0.01987798884510994
#
# Evaluating Network
# Mean Accuracy: 1.0000
# Avg loss: 0.008661924628540874
# Training accuracy on epoch 19 is 1.0
#
# Mean Accuracy: 0.7895
# Avg loss: 0.343784898519516
# Test (val) accuracy on epoch 19 is 0.7894736842105263
# ---------------------------------------
# 1.0
# ---------------------------------------

# %%
model = initializeModel()

load_model(model, save_dir, "best_model0.005.pth") # Load the trained weights
criterion = torch.nn.CrossEntropyLoss()
test_accuracy, test_loss= test(test_loader, model, criterion)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# <ipython-input-33-502905cec1a1>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(save_path))
# Mean Accuracy: 1.0000
# Avg loss: 0.011479995911940932
